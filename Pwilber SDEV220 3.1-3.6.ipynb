# %%
#3.1: How many seconds are in an hour?: 3600
Seconds_per_minute = 60
Minutes_per_hour = 60


print("There are", Seconds_per_minute * Minutes_per_hour, "seconds in an hour.")
# Out:
# There are 3600 seconds in an hour.

# %%
#3.2:
Seconds_per_hour = Seconds_per_minute * Minutes_per_hour
print(Seconds_per_hour)
# Out:
# 3600

# %%
#3.3: How many seconds are in a day?: 86400 
Hours_per_day = 24
print("There are", Seconds_per_hour * Hours_per_day, "seconds in a day.")
# Out:
# There are 86400 seconds in a day.

# %%
#3.4 
Seconds_per_day = Seconds_per_hour * Hours_per_day
print(Seconds_per_day)
# Out:
# 86400

# %%
#3.5
print(Seconds_per_day / Seconds_per_hour)
# Out:
# 24.0

# %%
#3.6: Did this number agree with the floating-point value from the previous question, aside from the final .0?: Yes
print(Seconds_per_day // Seconds_per_hour)
# Out:
# 24
